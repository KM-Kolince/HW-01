# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load Data Set
df = pd.read_csv('https://raw.githubusercontent.com/frankData612/data_612/master/baseballdatabank-master/core/Teams.csv')
df
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...   DP  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN  20  10  ...   24
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN  19   9  ...   16
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN  10  19  ...   15
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN   7  12  ...    8
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN  16  17  ...   14
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ..  ...  ...
# 2920    2019   NL    SLN      STL     C     1  162   81.0  91  71  ...  168
# 2921    2019   AL    TBA      TBD     E     2  162   81.0  96  66  ...  126
# 2922    2019   AL    TEX      TEX     W     3  162   81.0  78  84  ...  143
# 2923    2019   AL    TOR      TOR     E     4  162   81.0  67  95  ...  141
# 2924    2019   NL    WAS      WSN     E     2  162   81.0  93  69  ...  111
#
# ...

# %%
# Show the .head() of the data set
df.head(3)
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0   98       BOS             BS1          BS1
# 1  102       CHI             CH1          CH1
# 2  100       CLE             CL1          CL1
#
# [3 rows x 48 columns]

# %%
# Show the .tail() of the data set
df.tail(6)
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...   DP  \
# 2919    2019   NL    SFN      SFG     W     3  162   81.0  77  85  ...  142
# 2920    2019   NL    SLN      STL     C     1  162   81.0  91  71  ...  168
# 2921    2019   AL    TBA      TBD     E     2  162   81.0  96  66  ...  126
# 2922    2019   AL    TEX      TEX     W     3  162   81.0  78  84  ...  143
# 2923    2019   AL    TOR      TOR     E     4  162   81.0  67  95  ...  141
# 2924    2019   NL    WAS      WSN     E     2  162   81.0  93  69  ...  111
#
#          FP                  name                          park  attendance  \
# 2919  0.985  San Francisco Giants                   Oracle Park   2707760.0
# 2920  0.989   St. Louis Cardinals             Busch Stadium III   3480393.0
# 2921  0.985        Tampa Bay Rays               Tropicana Field   1178735.0
# 2922  0.982         Texas Rangers  Globe Life Park in Arlington   2132994.0
# ...

# %%
# Print coloumns name
print(df.columns)
# Out:
# Index(['yearID', 'lgID', 'teamID', 'franchID', 'divID', 'Rank', 'Ghome',
#        'DivWin', 'WCWin', 'LgWin', 'WSWin', 'name', 'park', 'attendance',
#        'BPF', 'PPF', 'teamIDBR', 'teamIDlahman45', 'teamIDretro'],
#       dtype='object')

# %%
# Print Data types
df.dtypes
# Out:
# yearID              int64
# lgID               object
# teamID             object
# franchID           object
# divID              object
# Rank                int64
# Ghome             float64
# DivWin             object
# WCWin              object
# LgWin              object
# WSWin              object
# name               object
# park               object
# attendance        float64
# BPF                 int64
# PPF                 int64
# teamIDBR           object
# teamIDlahman45     object
# teamIDretro        object
# dtype: object

# %%
# Print number of rows and columns
df.shape
# Out:
# (2925, 19)

# %%
df.isnull().sum()
# Out:
# yearID               0
# lgID                50
# teamID               0
# franchID             0
# divID             1517
# Rank                 0
# Ghome              399
# DivWin            1545
# WCWin             2181
# LgWin               28
# WSWin              357
# name                 0
# park                34
# attendance         279
# BPF                  0
# PPF                  0
# teamIDBR             0
# teamIDlahman45       0
# teamIDretro          0
# dtype: int64

# %%
df.groupby('name')['BPF'].mean().head()
# Out:
# name
# Altoona Mountain City    101.000000
# Anaheim Angels           100.125000
# Arizona Diamondbacks     105.409091
# Atlanta Braves           102.962963
# Baltimore Canaries       103.000000
# Name: BPF, dtype: float64

# %%
df.groupby(['name', 'yearID'])[['BPF','PPF']].mean()
# Out:
#                                 BPF    PPF
# name                  yearID
# Altoona Mountain City 1884    101.0  109.0
# Anaheim Angels        1997    102.0  102.0
#                       1998    102.0  102.0
#                       1999     99.0  100.0
#                       2000    102.0  103.0
# ...                             ...    ...
# Washington Statesmen  1891     95.0  100.0
# Wilmington Quicksteps 1884    103.0  109.0
# Worcester Ruby Legs   1880    108.0  109.0
#                       1881    105.0  108.0
#                       1882    102.0  107.0
#
# [2922 rows x 2 columns]
